# %% [markdown]
# # 1. 패키지 설치

# %% [markdown]
# ### 패키지 설치는 프로젝트 루트에서 uv sync 명령어로 진행

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록 (Upstage Console에서 발급받은 API Key)

# %%
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# # 3. LLM 예시 답변 생성해보기
#
# - Upstage Console에서 발급받은 API Key를 `UPSTAGE_API_KEY`라고 저장하면 별도의 설정 없이 `ChatUpstage`를 사용할 수 있음

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("직선을 짧게 정의하라.")

# %%
ai_message.content
